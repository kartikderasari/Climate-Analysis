# %%
import pandas as pd
data=pd.read_excel('weatherAUS.xlsx')
data
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1      2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2      2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3      2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4      2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...           ...      ...      ...      ...       ...          ...       ...
# 142188 2017-06-20    Uluru      3.5     21.8       0.0          NaN       NaN
# 142189 2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 142190 2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 142191 2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 142192 2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
#
# ...

# %%
data.RainTomorrow.replace(('Yes','No'),(1,0),inplace=True)
data.RainToday.replace(('Yes','No'),(1,0),inplace=True)
data
# Out:
#              Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0      2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1      2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2      2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3      2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4      2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ...           ...      ...      ...      ...       ...          ...       ...
# 142188 2017-06-20    Uluru      3.5     21.8       0.0          NaN       NaN
# 142189 2017-06-21    Uluru      2.8     23.4       0.0          NaN       NaN
# 142190 2017-06-22    Uluru      3.6     25.3       0.0          NaN       NaN
# 142191 2017-06-23    Uluru      5.4     26.9       0.0          NaN       NaN
# 142192 2017-06-24    Uluru      7.8     27.0       0.0          NaN       NaN
#
# ...

# %%
data=data.drop(['Date','Location','Evaporation','Sunshine','WindGustDir','WindDir9am','WindDir3pm'],axis=1)
data
# Out:
#         MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0          13.4     22.9       0.6           44.0          20.0          24.0
# 1           7.4     25.1       0.0           44.0           4.0          22.0
# 2          12.9     25.7       0.0           46.0          19.0          26.0
# 3           9.2     28.0       0.0           24.0          11.0           9.0
# 4          17.5     32.3       1.0           41.0           7.0          20.0
# ...         ...      ...       ...            ...           ...           ...
# 142188      3.5     21.8       0.0           31.0          15.0          13.0
# 142189      2.8     23.4       0.0           31.0          13.0          11.0
# 142190      3.6     25.3       0.0           22.0          13.0           9.0
# 142191      5.4     26.9       0.0           37.0           9.0           9.0
# 142192      7.8     27.0       0.0           28.0          13.0           7.0
#
# ...

# %%
data1=data.fillna(0)
data1
# Out:
#         MinTemp  MaxTemp  Rainfall  WindGustSpeed  WindSpeed9am  WindSpeed3pm  \
# 0          13.4     22.9       0.6           44.0          20.0          24.0
# 1           7.4     25.1       0.0           44.0           4.0          22.0
# 2          12.9     25.7       0.0           46.0          19.0          26.0
# 3           9.2     28.0       0.0           24.0          11.0           9.0
# 4          17.5     32.3       1.0           41.0           7.0          20.0
# ...         ...      ...       ...            ...           ...           ...
# 142188      3.5     21.8       0.0           31.0          15.0          13.0
# 142189      2.8     23.4       0.0           31.0          13.0          11.0
# 142190      3.6     25.3       0.0           22.0          13.0           9.0
# 142191      5.4     26.9       0.0           37.0           9.0           9.0
# 142192      7.8     27.0       0.0           28.0          13.0           7.0
#
# ...

# %%
x=data1.iloc[:,:-1].values
x
# Out:
# array([[13.4, 22.9,  0.6, ..., 21.8,  0. ,  0. ],
#        [ 7.4, 25.1,  0. , ..., 24.3,  0. ,  0. ],
#        [12.9, 25.7,  0. , ..., 23.2,  0. ,  0. ],
#        ...,
#        [ 3.6, 25.3,  0. , ..., 24.5,  0. ,  0. ],
#        [ 5.4, 26.9,  0. , ..., 26.1,  0. ,  0. ],
#        [ 7.8, 27. ,  0. , ..., 26. ,  0. ,  0. ]])

# %%
y=data[['RainTomorrow']]
y
# Out:
#         RainTomorrow
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 142188             0
# 142189             0
# 142190             0
# 142191             0
# 142192             0
#
# [142193 rows x 1 columns]

# %%
import numpy as np 
import pandas as pd
import statsmodels.api as sm
X = x
Y = y
model = sm.Logit(Y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.013083
#          Iterations 16
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:           RainTomorrow   No. Observations:               142193
# Model:                          Logit   Df Residuals:                   142177
# Method:                           MLE   Df Model:                           15
# Date:                Sat, 02 May 2020   Pseudo R-squ.:                  0.9754
# Time:                        12:48:50   Log-Likelihood:                -1860.3
# converged:                       True   LL-Null:                       -75668.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()
regressor.fit(x_train,y_train)
y_score_train = regressor.score(x_train,y_train)

print(y_score_train * 100)

regressor.fit(x_test,y_test)
y_score_test = regressor.score(x_test,y_test)

print(y_score_test * 100)
# Out:
# C:\Users\devan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\devan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 99.72371527603356
# C:\Users\devan\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\devan\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 99.95780392892306

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

y_train_pred=regressor.predict(x_train)
y_test_pred=regressor.predict(x_test)

# %%
print(accuracy_score(y_train,y_train_pred))
print(accuracy_score(y_test,y_test_pred))
# Out:
# 0.9994373838348319
# 0.9995780392892306

# %%
print(confusion_matrix(y_train,y_train_pred))
print(confusion_matrix(y_test,y_test_pred))
# Out:
# [[77239    35]
#  [   21 22240]]
# [[33028    14]
#  [    4  9612]]

# %%
print(classification_report(y_train,y_train_pred))
print(classification_report(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     77274
#            1       1.00      1.00      1.00     22261
#
#     accuracy                           1.00     99535
#    macro avg       1.00      1.00      1.00     99535
# weighted avg       1.00      1.00      1.00     99535
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     33042
#            1       1.00      1.00      1.00      9616
#
#     accuracy                           1.00     42658
#    macro avg       1.00      1.00      1.00     42658
# weighted avg       1.00      1.00      1.00     42658
